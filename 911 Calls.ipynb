# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Desktop/911.csv')
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %% [markdown]
# Top 5 zip codes

# %%
df['zip'].value_counts().head(5)
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %% [markdown]
# Top 5 townships (twp) for 911 calls?

# %%
df['twp'].value_counts().head(5)
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %% [markdown]
# Unique title codes in title column

# %%
df['title'].unique()
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
# ...

# %%
len(df['title'].unique())
# Out:
# 110

# %%
df['title'].nunique()
# Out:
# 110

# %% [markdown]
# Creating new column 'Reason'for the reason of 911 call

# %%
x = df['title'].iloc[0]

# %%
x
# Out:
# 'EMS: BACK PAINS/INJURY'

# %%
x.split(':')[0]
# Out:
# 'EMS'

# %%
df['Reason'] = df['title'].apply(lambda title: title.split(':')[0])

# %%
df['Reason']
# Out:
# 0            EMS
# 1            EMS
# 2           Fire
# 3            EMS
# 4            EMS
#           ...
# 99487    Traffic
# 99488    Traffic
# 99489        EMS
# 99490        EMS
# 99491    Traffic
# Name: Reason, Length: 99492, dtype: object

# %% [markdown]
# The most common Reason for 911 calls based of the new column

# %%
df['Reason'].value_counts()
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %% [markdown]
# Seaborn contplot of Reason

# %%
sns.countplot(x='Reason', data=df, palette='viridis')
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='count'>

# %% [markdown]
# Data type of the objects in the timeStamp column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
#  9   Reason     99492 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.6+ MB

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %% [markdown]
# Converting it into DateTime objects

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
time = df['timeStamp'].iloc[0]
time.hour
# Out:
# 17

# %% [markdown]
# Creating 3 new columns Hour,Month,Day of Week

# %%
time
# Out:
# Timestamp('2015-12-10 17:40:00')

# %%
time.hour
# Out:
# 17

# %%
time.month
# Out:
# 12

# %%
time.dayofweek
# Out:
# 3

# %%
df['Hour'] = df['timeStamp'].apply(lambda time: time.hour)

# %%
df['Hour']
# Out:
# 0        17
# 1        17
# 2        17
# 3        17
# 4        17
#          ..
# 99487    11
# 99488    11
# 99489    11
# 99490    11
# 99491    11
# Name: Hour, Length: 99492, dtype: int64

# %%
df['Month'] = df['timeStamp'].apply(lambda time: time.month)
df['Day of Week'] = df['timeStamp'].apply(lambda time: time.dayofweek)

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %% [markdown]
# Maping the actual name of the day, to replace the numbers in the day of Week column

# %%
dmap = {0:'Mon',1:'Tue',3:'Wed',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day of Week'] = df['Day of Week'].map(dmap)

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %% [markdown]
# Seaborn countplot of the day of week with hue based on the Reason column

# %%
sns.countplot(x='Day of Week',data = df, hue='Reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %% [markdown]
# seaborn countplot of the Month with hue based on the Reason column

# %%
sns.countplot(x='Month',data = df, hue='Reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %%
byMonth = df.groupby('Month').count()

# %%
byMonth.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
#
#        Reason   Hour  Day of Week
# Month
# 1       13205  13205        11505
# 2       11467  11467         9564
# 3       11101  11101         9212
# 4       11326  11326         9809
# 5       11423  11423         9885

# %%
byMonth['lat'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# lmplot to create linear fit on tje number of calls per month

# %%
byMonth.reset_index()
# Out:
#    Month    lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# 0      1  13205  13205  13205  11527  13205      13205  13203  13096  13205
# 1      2  11467  11467  11467   9930  11467      11467  11465  11396  11467
# 2      3  11101  11101  11101   9755  11101      11101  11092  11059  11101
# 3      4  11326  11326  11326   9895  11326      11326  11323  11283  11326
# 4      5  11423  11423  11423   9946  11423      11423  11420  11378  11423
# 5      6  11786  11786  11786  10212  11786      11786  11777  11732  11786
# 6      7  12137  12137  12137  10633  12137      12137  12133  12088  12137
# 7      8   9078   9078   9078   7832   9078       9078   9073   9025   9078
# 8     12   7969   7969   7969   6907   7969       7969   7963   7916   7969
#
#    Reason   Hour  Day of Week
# 0   13205  13205        11505
# 1   11467  11467         9564
# 2   11101  11101         9212
# 3   11326  11326         9809
# 4   11423  11423         9885
# ...

# %%
sns.lmplot(x='Month',y='twp',data=byMonth.reset_index())

# %% [markdown]
# Creating a new column Date

# %%
t = df['timeStamp'].iloc[0]

# %%
t
# Out:
# Timestamp('2015-12-10 17:40:00')

# %%
t.date()
# Out:
# datetime.date(2015, 12, 10)

# %%
df['Date'] = df['timeStamp'].apply(lambda t:t.date())

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
# ...

# %% [markdown]
# Groupby() on date column

# %%
df.groupby('Date').count().head()
# Out:
#             lat  lng  desc  zip  title  timeStamp  twp  addr    e  Reason  \
# Date
# 2015-12-10  115  115   115  100    115        115  115   113  115     115
# 2015-12-11  396  396   396  333    396        396  395   391  396     396
# 2015-12-12  403  403   403  333    403        403  403   401  403     403
# 2015-12-13  319  319   319  280    319        319  319   317  319     319
# 2015-12-14  447  447   447  387    447        447  446   445  447     447
#
#             Hour  Month  Day of Week
# Date
# 2015-12-10   115    115          115
# 2015-12-11   396    396          396
# 2015-12-12   403    403          403
# 2015-12-13   319    319          319
# 2015-12-14   447    447          447

# %%
df.groupby('Date').count()['lat']
# Out:
# Date
# 2015-12-10    115
# 2015-12-11    396
# 2015-12-12    403
# 2015-12-13    319
# 2015-12-14    447
#              ...
# 2016-08-20    328
# 2016-08-21    357
# 2016-08-22    389
# 2016-08-23    439
# 2016-08-24    132
# Name: lat, Length: 259, dtype: int64

# %%
df.groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
df[df['Reason']=='Traffic'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('Traffic')
# Out:
# Text(0.5, 1.0, 'Traffic')

# %%
df[df['Reason']=='Fire'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('Fire')
# Out:
# Text(0.5, 1.0, 'Fire')

# %%
df[df['Reason']=='EMS'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('EMS')
# Out:
# Text(0.5, 1.0, 'EMS')

# %%
df.groupby(by=['Day of Week','Hour']).count()
# Out:
#                   lat  lng  desc  zip  title  timeStamp  twp  addr    e  \
# Day of Week Hour
# Fri         0     275  275   275  248    275        275  275   275  275
#             1     235  235   235  200    235        235  235   232  235
#             2     191  191   191  165    191        191  191   191  191
#             3     175  175   175  164    175        175  175   175  175
#             4     201  201   201  184    201        201  201   201  201
# ...               ...  ...   ...  ...    ...        ...  ...   ...  ...
# Wed         19    698  698   698  610    698        698  698   694  698
#             20    617  617   617  543    617        617  617   614  617
#             21    553  553   553  472    553        553  553   550  553
#             22    424  424   424  356    424        424  424   424  424
#             23    354  354   354  307    354        354  354   354  354
#
#                   Reason  Month  Date
# Day of Week Hour
# ...

# %%
dayHour = df.groupby(by=['Day of Week','Hour']).count()['Reason'].unstack()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dayHour, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Day of Week'>

# %%
sns.clustermap(dayHour,cmap='viridis')

# %%
dayMonth = df.groupby(by=['Day of Week','Month']).count()['Reason'].unstack()

# %%
dayMonth.head()
# Out:
# Month          1     2     3     4     5     6     7     8     12
# Day of Week
# Fri          1970  1581  1525  1958  1730  1649  2045  1310  1065
# Mon          1727  1964  1535  1598  1779  1617  1692  1511  1257
# Sat          2291  1441  1266  1734  1444  1388  1695  1099   978
# Sun          1960  1229  1102  1488  1424  1333  1672  1021   907
# Tue          1973  1753  1884  1430  1918  1676  1670  1612  1234

# %%
plt.figure(figsize=(12,6))
sns.heatmap(dayMonth, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Day of Week'>

# %%
sns.clustermap(dayMonth,cmap='viridis')

# %%
sns.clustermap(dayMonth,cmap='coolwarm')
